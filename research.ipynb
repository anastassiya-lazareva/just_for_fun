# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('Датасет.csv')
df = df.set_index('Наименование')
df.columns = pd.to_datetime(df.columns, dayfirst=True)
df = df.dropna()
df.head()
# Out:
#                                        2022-01-10  2022-01-14  2022-01-21  \
# Наименование
# Говядина (кроме бескостного мяса), кг      415.98      417.00      418.04
# Свинина (кроме бескостного мяса), кг       309.36      308.54      308.44
# Баранина (кроме бескостного мяса), кг      504.45      504.63      506.76
# Куры охлажденные и мороженые, кг           182.12      181.35      180.36
# Сосиски, сардельки, кг                     433.27      432.54      434.56
#
#                                        2022-01-28  2022-02-04  2022-02-11  \
# Наименование
# Говядина (кроме бескостного мяса), кг      419.40      424.53      425.41
# Свинина (кроме бескостного мяса), кг       309.00      308.10      307.34
# Баранина (кроме бескостного мяса), кг      508.39      497.90      498.92
# Куры охлажденные и мороженые, кг           179.89      180.11      179.72
# Сосиски, сардельки, кг                     435.28      433.59      432.49
#
#                                        2022-02-18  2022-02-25  2022-03-04  \
# Наименование
# Говядина (кроме бескостного мяса), кг      426.85      428.51      432.61
# Свинина (кроме бескостного мяса), кг       306.76      306.08      306.74
# Баранина (кроме бескостного мяса), кг      500.72      501.81      502.89
# Куры охлажденные и мороженые, кг           179.62      179.30      179.20
# Сосиски, сардельки, кг                     434.93      435.64      436.34
#
#                                        2022-03-11  ...  2025-04-28  \
# Наименование                                       ...
# Говядина (кроме бескостного мяса), кг      436.44  ...      635.86
# Свинина (кроме бескостного мяса), кг       310.69  ...      376.04
# Баранина (кроме бескостного мяса), кг      503.43  ...      811.82
# Куры охлажденные и мороженые, кг           179.94  ...      216.00
# Сосиски, сардельки, кг                     438.29  ...      531.25
#
#                                        2025-05-05  2025-05-12  2025-05-19  \
# Наименование
# Говядина (кроме бескостного мяса), кг      636.14      637.31      638.93
# Свинина (кроме бескостного мяса), кг       377.75      379.54      380.38
# Баранина (кроме бескостного мяса), кг      818.12      818.27      819.55
# Куры охлажденные и мороженые, кг           217.68      220.03      222.45
# Сосиски, сардельки, кг                     530.05      530.89      533.49
#
#                                        2025-05-26  2025-06-02  2025-06-09  \
# Наименование
# Говядина (кроме бескостного мяса), кг      640.06      641.04      641.35
# Свинина (кроме бескостного мяса), кг       382.32      383.20      383.22
# Баранина (кроме бескостного мяса), кг      817.16      818.60      818.12
# Куры охлажденные и мороженые, кг           224.28      225.14      225.92
# Сосиски, сардельки, кг                     535.19      535.45      536.01
#
#                                        2025-06-16  2025-06-23  2025-06-30
# Наименование
# Говядина (кроме бескостного мяса), кг      642.09      643.02      644.38
# Свинина (кроме бескостного мяса), кг       383.77      384.19      384.50
# Баранина (кроме бескостного мяса), кг      813.61      813.44      814.61
# Куры охлажденные и мороженые, кг           226.77      227.27      227.16
# Сосиски, сардельки, кг                     534.26      535.07      535.68
#
# [5 rows x 179 columns]

# %%
#создадим датасет с темпами прироста цен 2022, 2023, 2024, 2022-2025

columns_2022 = [col for col in df.columns if col.year == 2022]
columns_2023 = [col for col in df.columns if col.year == 2023]
columns_2024 = [col for col in df.columns if col.year == 2024]
columns_2025 = [col for col in df.columns if col.year == 2025]

growth_rate = pd.DataFrame()

growth_rate['2022'] = (df[max(columns_2022)] - df[min(columns_2022)])/ df[min(columns_2022)]*100
growth_rate['2023'] = (df[max(columns_2023)] - df[min(columns_2023)])/ df[min(columns_2023)]*100
growth_rate['2024'] = (df[max(columns_2024)] - df[min(columns_2024)])/ df[min(columns_2024)]*100
growth_rate['2022-2025'] = (df[max(columns_2025)] - df[min(columns_2022)])/ df[min(columns_2022)]*100

growth_rate.head()
# Out:
#                                             2022       2023       2024  \
# Наименование
# Говядина (кроме бескостного мяса), кг  16.392615   7.487283  13.929641
# Свинина (кроме бескостного мяса), кг   -0.465477  12.767349   6.314688
# Баранина (кроме бескостного мяса), кг   9.578749  14.542466  27.124571
# Куры охлажденные и мороженые, кг       -2.141445  27.940184  -0.455490
# Сосиски, сардельки, кг                  8.419692   6.986079   6.316758
#
#                                        2022-2025
# Наименование
# Говядина (кроме бескостного мяса), кг  54.906486
# Свинина (кроме бескостного мяса), кг   24.288854
# Баранина (кроме бескостного мяса), кг  61.484785
# Куры охлажденные и мороженые, кг       24.730947
# Сосиски, сардельки, кг                 23.636531

# %%
#Найдем топ-5 подорожавших товаров и топ-5 товаров с наименьшим приростом
top5_exp = list(growth_rate['2022-2025'].sort_values()[-5:].index)
top5_ch = list(growth_rate['2022-2025'].sort_values()[:5].index)
print(f"Топ 5 подорожавших товаров: {'; '.join(top5_exp)}\nТоп-5 товаров с наименьшим приростом: {'; '.join(top5_ch)}")
# Out:
# Топ 5 подорожавших товаров: Бананы, кг; Спички, коробок; Картофель, кг; Свёкла столовая, кг; Лук репчатый, кг
# Топ-5 товаров с наименьшим приростом: Крупа гречневая-ядрица, кг; Огурцы свежие, кг; Плиты древесностружечные, ориентированно-стружечные, м2; Телевизор, шт.; Яйца куриные, 10 шт.

# %%
#Посмотрим, как выглядит распределение прироста цен за разные года
fig, axes = plt.subplots(2, 2, figsize=(14, 10), sharey=True)

years = ['2022', '2023', '2024', '2022-2025']
colors = ['skyblue', 'lightgreen', 'salmon', 'orchid']

axes = axes.flatten()

all_data = pd.concat([growth_rate[year] for year in years])
x_min, x_max = all_data.min(), all_data.max()

for i, year in enumerate(years):
    sns.histplot(growth_rate[year], kde=True, bins=20, color=colors[i], ax=axes[i])

    mean_value = growth_rate[year].mean()
    st_dev = growth_rate[year].std()

    axes[i].axvline(mean_value, color='black', linestyle='--', linewidth=2, label=f'Среднее: {mean_value:.2f}\nСреднекв. откл.:{st_dev:.2f} ')
    axes[i].legend() 

    axes[i].set_xlim(x_min, x_max)
    axes[i].set_title(f'Прирост цен ({year})', fontsize=12)
    axes[i].set_xlabel('Прирост (%)')

    if i % 2 == 0:
        axes[i].set_ylabel('Кол-во товаров')
    else:
        axes[i].set_ylabel('')

plt.tight_layout()
plt.show()

# %% [markdown]
# Проинтерпретируем полученные графики: <br> 1. Гистограмма распределения прироста цен в 2022 практически симметрична, однако есть выбросы с отрицательным приростом, образующие левый хвост; <br> 2. В 2023 году график становится уже (меньше колебаний цен), причем средний прирост выше;<br> 3. В 2024 году распределение с выраженным правым хвостом, что говорит о том, что часть товаров выросла довольно сильно в цене; <br> 4. Совокупный прирост: распределение смещено вправо, часть товаров существенно подорожало, хвосты длинные

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=growth_rate, x='2022', y='2023')

plt.title('Сравнение приростов: 2022 vs 2023')
plt.xlabel('Прирост в 2022 (%)')
plt.ylabel('Прирост в 2023 (%)')
plt.grid(True)
plt.show()

# %%
#Функция, которая убирает выбросы
def find_outliers (data):
    Q1 = data.quantile(0.25)
    Q3 = data.quantile(0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    outliers = data[(data < lower_bound) | (data > upper_bound)].sort_values()
    return outliers
find_outliers(growth_rate['2024'])
# Out:
# Наименование
# Яйца куриные, 10 шт.                    -12.876978
# Смартфон, шт.                            -7.345957
# Крупа гречневая-ядрица, кг               -5.618874
# Баранина (кроме бескостного мяса), кг    27.124571
# Свёкла столовая, кг                      29.069767
# Капуста белокочанная свежая, кг          35.752764
# Масло сливочное, кг                      38.366923
# Лук репчатый, кг                         45.117845
# Картофель, кг                            93.598910
# Name: 2024, dtype: float64

# %%
years = ['2022', '2023', '2024', '2022-2025']

for year in years:
    Q1 = growth_rate[year].quantile(0.25)
    Q3 = growth_rate[year].quantile(0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    growth_rate[year] = growth_rate[year].where(
        (growth_rate[year] >= lower_bound) & (growth_rate[year] <= upper_bound)
    )

# %%
fig, axes = plt.subplots(2, 2, figsize=(14, 10), sharey=True)

years = ['2022', '2023', '2024', '2022-2025']
colors = ['skyblue', 'lightgreen', 'salmon', 'orchid']

axes = axes.flatten()

all_data = pd.concat([growth_rate[year] for year in years])
x_min, x_max = all_data.min(), all_data.max()

for i, year in enumerate(years):
    sns.histplot(growth_rate[year], kde=True, bins=20, color=colors[i], ax=axes[i])

    mean_value = growth_rate[year].mean()
    st_dev = growth_rate[year].std()

    axes[i].axvline(mean_value, color='black', linestyle='--', linewidth=2, label=f'Среднее: {mean_value:.2f}\nСреднекв. откл.:{st_dev:.2f} ')
    axes[i].legend() 

    axes[i].set_xlim(x_min, x_max)
    axes[i].set_title(f'Прирост цен ({year})', fontsize=12)
    axes[i].set_xlabel('Прирост (%)')

    if i % 2 == 0:
        axes[i].set_ylabel('Кол-во товаров')
    else:
        axes[i].set_ylabel('')

plt.tight_layout()
plt.show()
