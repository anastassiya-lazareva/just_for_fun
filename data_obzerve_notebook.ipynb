# %%
import pandas as pd
import re
from datetime import datetime
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
# Посмотрим, какие листы есть в этом файле
xls = pd.ExcelFile("Nedel_sred_cen.xlsx")
print(xls.sheet_names)
# Out:
# ['Содержание', '2022', '2023', '2024', '2025']

# %%
#Отбросим содержание, прочитаем только листы с данными
sheet_names = xls.sheet_names 
sheets_to_read = sheet_names[1:]
all_sheets = pd.read_excel("Nedel_sred_cen.xlsx", sheet_name=sheets_to_read, skiprows=3)

# %%
# Посмотрим на данные
all_sheets["2022"]
# Out:
#                                           Наименование на 10 января  \
# 0                Говядина (кроме бескостного мяса), кг       415.98
# 1                 Свинина (кроме бескостного мяса), кг       309.36
# 2                Баранина (кроме бескостного мяса), кг       504.45
# 3                     Куры охлажденные и мороженые, кг       182.12
# 4                               Сосиски, сардельки, кг       433.27
# ..                                                 ...          ...
# 104                Услуги по снабжению электроэнергией        393.8
# 105                 Поездка на отдых в Турцию, поездка     28889.45
# 106                                    Санаторий, день      3268.53
# 107                        Дом отдыха, пансионат, день         2026
# 108  * Без учета статистической информации по Донец...          NaN
#
#     на 14 января на 21 января на 28 января на 4 февраля на 11 февраля  \
# 0            417       418.04        419.4       424.53        425.41
# ...

# %%
# Уберем строки с пропусками
for sheet_name, df in all_sheets.items():
    all_sheets[sheet_name] = df.dropna()
    all_sheets[sheet_name] = df.set_index('Наименование')
    all_sheets[sheet_name] = all_sheets[sheet_name].applymap(lambda x: pd.to_numeric(x, errors='coerce'))

# %%
# Приведем все заголовки к единому виду: "на 10 января" -> "10.01.2022" в формате datetime64[ns]
month_map = {
    'января': 1,
    'февраля': 2,
    'марта': 3,
    'апреля': 4,
    'мая': 5,
    'июня': 6,
    'июля': 7,
    'августа': 8,
    'сентября': 9,
    'октября': 10,
    'ноября': 11,
    'декабря': 12
}
for sheet_name, df in all_sheets.items():
    match = re.search(r'\d{4}', sheet_name)
    if not match:
        continue
    year = int(match.group())
    new_columns = []
    for col in df.columns:
        match = re.match(r'на\s+(\d{1,2})\s+([а-яА-Я]+)', str(col).strip().lower())
        if match:
            day = int(match.group(1))
            month_name = match.group(2)
            month = month_map[month_name.lower()]
            date_obj = datetime(year, month, day)
            new_columns.append(date_obj.strftime("%d.%m.%Y"))
        else:
            new_columns.append(col)  # не дата — оставить как есть

    df.columns = new_columns  # заменить заголовки
    all_sheets[sheet_name] = df  # сохранить обратно

# %%
# Посмотрим, как теперь выглядят заголовки
df_2022 = all_sheets['2022']
df_2022.head()
# Out:
#                                        10.01.2022  14.01.2022  21.01.2022  \
# Наименование
# Говядина (кроме бескостного мяса), кг      415.98      417.00      418.04
# Свинина (кроме бескостного мяса), кг       309.36      308.54      308.44
# Баранина (кроме бескостного мяса), кг      504.45      504.63      506.76
# Куры охлажденные и мороженые, кг           182.12      181.35      180.36
# Сосиски, сардельки, кг                     433.27      432.54      434.56
#
#                                        28.01.2022  04.02.2022  11.02.2022  \
# Наименование
# Говядина (кроме бескостного мяса), кг      419.40      424.53      425.41
# Свинина (кроме бескостного мяса), кг       309.00      308.10      307.34
# Баранина (кроме бескостного мяса), кг      508.39      497.90      498.92
# Куры охлажденные и мороженые, кг           179.89      180.11      179.72
# Сосиски, сардельки, кг                     435.28      433.59      432.49
#
# ...

# %%
sosiges = 'Сосиски, сардельки, кг'
row_sosiges = df_2022.loc[sosiges]
prices = row_sosiges.values
row_sosiges.index = pd.to_datetime(row_sosiges.index, dayfirst=True)


plt.figure(figsize=(10, 5))
plt.plot(row_sosiges.index, prices, marker='o')

ax = plt.gca()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%d.%m.%y'))

plt.title(f'Изменение цены на {sosiges} в 2022')
plt.xticks(rotation=45)
plt.xlabel("Дата")
plt.ylabel("Цена")
plt.grid(True)
plt.show()

# %%
#попробуем посмотреть на эти же данныес помощью библиотекм seaborn
import seaborn as sns

df_sosiges_plot = pd.DataFrame({
    'Дата': row_sosiges.index,
    'Цена': row_sosiges.values,
    'Товар': sosiges
})
plt.figure(figsize=(10, 5))
sns.lineplot(data=df_sosiges_plot, x='Дата', y='Цена', marker='o')

ax = plt.gca()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%d.%m.%y'))

plt.title(f'Изменение цены на {sosiges} в 2022')
plt.xticks(rotation=45)
plt.xlabel("Дата")
plt.ylabel("Цена")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
#посмотрим теперь на данные по сосискам за 2022-2025
df_all_years = pd.concat([df_2022, all_sheets['2023'],all_sheets['2024'],all_sheets['2025']], axis = 1)
df_all_years.columns = pd.to_datetime(df_all_years.columns, dayfirst=True)


row_sosiges_all_time = df_all_years.loc[sosiges]
prices_all_time = row_sosiges_all_time.values


df_sosiges_plot_all_time = pd.DataFrame({
    'Дата': row_sosiges_all_time.index,
    'Цена': row_sosiges_all_time.values,
    'Товар': sosiges
})
plt.figure(figsize=(10, 5))
sns.lineplot(data=df_sosiges_plot_all_time, x='Дата', y='Цена', marker='o')

ax = plt.gca()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%d.%m.%y'))

plt.title(f'Изменение цены на {sosiges} в 2022-2025')
plt.xticks(rotation=45)
plt.xlabel("Дата")
plt.ylabel("Цена")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
#Хочется найти товар, который больше/меньше всего подорожал за это время
percent_change = pd.concat([df_all_years[df_all_years.columns[0]], df_all_years[df_all_years.columns[-1]]], axis=1)
percent_change = percent_change.dropna()
percent_change['Прирост в процентах'] = (percent_change.iloc[:, 1] - percent_change.iloc[:, 0])/percent_change.iloc[:, 0] * 100
idx_max = percent_change['Прирост в процентах'].idxmax()
idx_min = percent_change['Прирост в процентах'].idxmin()
print(f'Товар, цена на который выросла больше всего - {idx_max}, меньше всего - {idx_min}')
# Out:
# Товар, цена на который выросла больше всего - Лук репчатый, кг, меньше всего - Крупа гречневая-ядрица, кг

# %%
#посмотрим на графики цен этих товаров
products = [idx_min, idx_max]
df_all_years.columns = pd.to_datetime(df_all_years.columns, dayfirst=True)

df_plot = df_all_years.loc[products].transpose().melt(var_name='Товар', value_name='Цена', ignore_index=False)
df_plot.reset_index(inplace=True)
df_plot.rename(columns={'index': 'Дата'}, inplace=True)

plt.figure(figsize=(10, 5))
sns.lineplot(data=df_plot, x='Дата', y='Цена', hue='Товар', marker='o')

ax = plt.gca()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%d.%m.%y'))

plt.title('Изменение цен в 2022–2025')
plt.xlabel("Дата")
plt.ylabel("Цена")
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()
