# %%
import pandas as pd

# %%
# Посмотрим, какие листы есть в этом файле
xls = pd.ExcelFile("Nedel_sred_cen.xlsx")
print(xls.sheet_names)
# Out:
# ['Содержание', '2022', '2023', '2024', '2025']

# %%
all_sheets = pd.read_excel("Nedel_sred_cen.xlsx", sheet_name=None, skiprows=3)

# %%
df_2022 = all_sheets["2022"]
df_2022.head()
# Out:
#                             Наименование на 10 января на 14 января  \
# 0  Говядина (кроме бескостного мяса), кг       415.98          417
# 1   Свинина (кроме бескостного мяса), кг       309.36       308.54
# 2  Баранина (кроме бескостного мяса), кг       504.45       504.63
# 3       Куры охлажденные и мороженые, кг       182.12       181.35
# 4                 Сосиски, сардельки, кг       433.27       432.54
#
#   на 21 января на 28 января на 4 февраля на 11 февраля на 18 февраля  \
# 0       418.04        419.4       424.53        425.41        426.85
# 1       308.44          309        308.1        307.34        306.76
# 2       506.76       508.39        497.9        498.92        500.72
# 3       180.36       179.89       180.11        179.72        179.62
# 4       434.56       435.28       433.59        432.49        434.93
#
#   на 25 февраля на 4 марта  ... на 24 октября на 31 октября на 7 ноября  \
# 0        428.51     432.61  ...        479.24        479.81      479.73
# 1        306.08     306.74  ...        309.21        309.56      309.27
# 2        501.81     502.89  ...        549.94        549.22       549.7
# 3         179.3      179.2  ...        181.77        181.65      181.41
# 4        435.64     436.34  ...         467.7        468.42      468.97
#
#   на 14 ноября на 21 ноября на 28 ноября на 5 декабря на 12 декабря  \
# 0       480.87       481.13       481.51       481.53        481.89
# 1       308.36       307.72       308.58       308.26        308.35
# 2       549.55       550.42       550.82          551        552.94
# 3       180.71       180.39        179.7       179.21        178.47
# 4       467.21       465.97       467.78       469.15        468.31
#
#   на 19 декабря на 26 декабря
# 0        482.81        484.17
# 1        307.54        307.92
# 2        553.16        552.77
# 3        177.81        178.22
# 4        467.96        469.75
#
# [5 rows x 52 columns]
